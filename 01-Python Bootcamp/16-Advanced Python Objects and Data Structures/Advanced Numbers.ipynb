# %%
hex(246)
# Out:
# '0xf6'

# %%
hex(512)
# Out:
# '0x200'

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(127)
# Out:
# '0b1111111'

# %%
pow(3,4)
# Out:
# 81

# %%
pow(3,4,5)
# Out:
# 1

# %%
abs(-3.14)
# Out:
# 3.14

# %%
abs(3)
# Out:
# 3

# %%
round(3.5)
# Out:
# 4

# %%
round(395, -2)
# Out:
# 400

# %%
round(3.1415926535,2)
# Out:
# 3.14
