# %%
import string
import random

print("#{:06x}".format(random.randint(0,0xFFFFFF)))
max_length=255
s=''
for i in range(random.randint(1,max_length)):
    s+=random.choice(string.ascii_letters)
print(s)
print(random.randint(0,10))
print(random.randint(-7,7))
print(random.randint(1,1))
print(random.randint(0,10)*7)
# Out:
# #d9f17c
# vLxNtueaSUXwGvweLfFxmRCeebsWsAUjNMKcAGmviyTLmqVClvJZPXccOrrFVgMhpmCKbyZRoQldcvtbJogFqoAmJSiFtIkNwCFvFeJtSLSFfHqyEEfIZsxxlDqN
# 10
# -3
# 1
# 49

# %%
import os
elements=[1,2,3,4,5]
print(random.choice(elements))

elements=set([1,2,3,4,5])
print(random.choice(tuple(elements)))

d={"a":1,"b":2,"c":3,"d":4,"e":5}
key=random.choice(list(d))
print(d[key])

print(random.choice(os.listdir("/")))
# Out:
# 5
# 5
# 2
# swapfile.sys
