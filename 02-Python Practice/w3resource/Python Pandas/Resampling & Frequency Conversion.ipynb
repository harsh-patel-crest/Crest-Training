# %%
import pandas as pd
import numpy as np

date_rng=pd.date_range(start='2023-01-01',end='2023-01-05',freq='h')
ts=pd.Series(np.random.randn(len(date_rng)), index=date_rng)

ts_daily=ts.resample('D').mean()

print(ts_daily)
# Out:
# 2023-01-01   -0.096249
# 2023-01-02    0.121950
# 2023-01-03    0.241045
# 2023-01-04    0.195838
# 2023-01-05   -1.672945
# Freq: D, dtype: float64

# %%
date_rng=pd.date_range(start='2023-01-01',end='2023-01-05',freq='D')
ts=pd.Series(np.random.randn(len(date_rng)), index=date_rng)

ts_hourly=ts.resample('h').ffill()

print(ts_hourly)
# Out:
# 2023-01-01 00:00:00    1.208125
# 2023-01-01 01:00:00    1.208125
# 2023-01-01 02:00:00    1.208125
# 2023-01-01 03:00:00    1.208125
# 2023-01-01 04:00:00    1.208125
#                          ...
# 2023-01-04 20:00:00    1.367037
# 2023-01-04 21:00:00    1.367037
# 2023-01-04 22:00:00    1.367037
# 2023-01-04 23:00:00    1.367037
# 2023-01-05 00:00:00   -0.445261
# Freq: h, Length: 97, dtype: float64

# %%
date_rng = pd.date_range(start='2023-01-01', end='2023-01-05', freq='h')
ts = pd.Series(np.random.randn(len(date_rng)), index=date_rng)

ts_daily_mean = ts.resample('D').mean()
ts_daily_sum = ts.resample('D').sum()
ts_daily_max = ts.resample('D').max()

print("Daily Mean:\n", ts_daily_mean)
print("Daily Sum:\n", ts_daily_sum)
print("Daily Max:\n", ts_daily_max)
# Out:
# Daily Mean:
#  2023-01-01    0.133062
# 2023-01-02    0.053264
# 2023-01-03    0.430329
# 2023-01-04    0.141667
# 2023-01-05    0.616042
# Freq: D, dtype: float64
# Daily Sum:
#  2023-01-01     3.193494
# 2023-01-02     1.278343
# 2023-01-03    10.327906
# 2023-01-04     3.400011
# 2023-01-05     0.616042
# Freq: D, dtype: float64
# Daily Max:
#  2023-01-01    1.514713
# 2023-01-02    2.688713
# 2023-01-03    2.539437
# 2023-01-04    2.507322
# 2023-01-05    0.616042
# Freq: D, dtype: float64

# %%
date_rng = pd.date_range(start='2021-01-01', end='2021-02-01', freq='D')
ts = pd.Series(np.random.randn(len(date_rng)), index=date_rng)

ts_weekly = ts.resample('W').mean()

print(ts_weekly)
# Out:
# 2021-01-03    0.796942
# 2021-01-10    0.201477
# 2021-01-17   -0.796583
# 2021-01-24    0.258365
# 2021-01-31    0.034210
# 2021-02-07   -0.411897
# Freq: W-SUN, dtype: float64
