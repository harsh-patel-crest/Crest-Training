# %%
var1=...
def print_arg(*args):
    for i, arg in enumerate(args):
        print(f'Arguments {i+1}:{arg}')
    if not args:
        print(var1)

print_arg(1,2,3,"Harsh")
print_arg(50,[1,2,3],'Crest Infosystems')
print_arg()
# Out:
# Arguments 1:1
# Arguments 2:2
# Arguments 3:3
# Arguments 4:Harsh
# Arguments 1:50
# Arguments 2:[1, 2, 3]
# Arguments 3:Crest Infosystems
# Ellipsis

# %%
def call_func(func,*args,**kwargs):
    return func(*args,**kwargs)

def add(x,y):
    return x+y

result=call_func(add,10,22)
print(result)

def message(name,text="Good Morning"):
    return f'{text} {name}'

result=call_func(message,'Harsh', text=...)
print(result)
# Out:
# 32
# Ellipsis Harsh
