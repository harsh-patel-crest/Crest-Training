# %%
data=bytearray(b'Harsh')
mv=memoryview(data)
print(data)

mv[0]=68

print(data)
print(mv.tobytes())
# Out:
# bytearray(b'Harsh')
# bytearray(b'Darsh')
# b'Darsh'

# %%
data=b'Python Exercises!'
mem_data=memoryview(data)
print(len(mem_data))
print(mem_data[:8])
# Out:
# 17
# <memory at 0x000002EFD9A26140>

# %%
def memoryview_to_bytes(mem_view):
    bytes_data=bytes(mem_view)
    return bytes_data

data=b'Python Exercises!'
mem_view=memoryview(data)
print(mem_view)
bytes_data=memoryview_to_bytes(mem_view)

print(bytes_data)
# Out:
# <memory at 0x000002EFD9A26440>
# b'Python Exercises!'
