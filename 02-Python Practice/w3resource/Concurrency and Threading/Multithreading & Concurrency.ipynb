# %%
import threading
def print_thread_names():
    print(threading.current_thread().name)

threads=[]
for i in range(4):
    thread=threading.Thread(target=print_thread_names)
    threads.append(thread)
    thread.start()

for thread in threads:
    thread.join()
# Out:
# Thread-3 (print_thread_names)
# Thread-4 (print_thread_names)
# Thread-5 (print_thread_names)
# Thread-6 (print_thread_names)

# %%
def print_even_numbers():
    print("List of even numbers:")
    for i in range(30, 51, 2):
        print(i, end = " ")

def print_odd_numbers():
    print("\nList of odd numbers:")
    for i in range(31, 51, 2):
        print(i, end = " ")
        
even_thread = threading.Thread(target=print_even_numbers)
odd_thread = threading.Thread(target=print_odd_numbers)
even_thread.start()
odd_thread.start()
even_thread.join()
odd_thread.join()
# Out:
# List of even numbers:
# 30 32 34 36 38 40 42 44 46 48 50
# List of odd numbers:
# 31 33 35 37 39 41 43 45 47 49
