# %%
from array import *
a = array('i', [1, 3, 5, 7, 3, 9, 5, 3])

# %%
print(a[0], a[1], a[2])
# Out:
# 1 3 5

# %%
a.append(6)
a
# Out:
# array('i', [1, 3, 5, 7, 3, 9, 5, 3, 6])

# %%
a.reverse()
a
# Out:
# array('i', [6, 3, 5, 9, 3, 7, 5, 3, 1])

# %%
a.itemsize
# Out:
# 4

# %%
a.count(3)
# Out:
# 3

# %%
print(a)
# Out:
# array('i', [6, 3, 5, 9, 3, 7, 5, 3, 1])

# %%
l=[1,5,8,2,6]
for i in l:
    a.append(i)

# %%
print(a)
# Out:
# array('i', [6, 3, 5, 9, 3, 7, 5, 3, 1, 1, 5, 8, 2, 6])

# %%
a.insert(1,1)
print(a)
# Out:
# array('i', [6, 1, 3, 5, 9, 3, 7, 5, 3, 1, 1, 5, 8, 2, 6])
